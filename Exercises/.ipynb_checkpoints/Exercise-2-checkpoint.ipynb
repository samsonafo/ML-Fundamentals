# %% [markdown]
# ##### To Do
#
# - Load in the train data for the Housing prices Competition.
# - Understand the data
# - Using the skills learnt, improve on your submission from exercise 1
# - build a model on train data
# - make prediction on test
# - submit predictions on the kaggle competition.

# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load data
iowa_file_path = '../data/Housing Prices Competition/train.csv'

df = pd.read_csv(iowa_file_path)

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# #### Data Exploration

# %%
print('The dataframe has {} columns and {} rows'.format(df.shape[1],df.shape[0]))
# Out:
# The dataframe has 81 columns and 1460 rows

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Get names of columns with missing values
cols_with_missing = [col for col in df.columns if df[col].isnull().any()]

#check for count of missing values in each columns
df[cols_with_missing].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
#create a list of all columns to drop
not_needed_cols = ['LotFrontage','Alley','FireplaceQu','PoolQC','Fence','MiscFeature']

# %%
#check for correlation matrix

corrmat = df.corr()   #get correlations table
top_corr_features = corrmat.index
plt.figure(figsize=(25,12))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")   #plot heat map

# %%
high_corr_columns = ['1stFlrSF','MSSubClass','Id','OverallCond','3SsnPorch','YrSold','BsmtHalfBath','LowQualFinSF','PoolArea']

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# ##### steps
# - Remove Id
# - Remove columns with a lot of missing values
# - Replace Nulls in numerical values with mean values
# - drop all highly correlated columns
# - drop all columns with huge missing values
# - Change Year to Age

# %%
#set X and y

X = df.drop('SalePrice',axis=1)
y = df.SalePrice

# %%
#drop all unneeded columns

def drop_columns(df):
    df = df.drop(high_corr_columns, axis=1)
    df = df.drop(not_needed_cols, axis=1)
    return df

# %%
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X.columns if X[cname].nunique() < 5 and X[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]

# %%
#replace all missing values in numerical columns with mean
numerical_transformer = SimpleImputer(strategy='mean')

#replace all missing values in categorical columns with the mode
categorical_transformer = Pipeline(steps=[ ('imputer', SimpleImputer(strategy='most_frequent')),
                                            ('ordinal', OneHotEncoder(handle_unknown='ignore'))
                                            ])

# %% [markdown]
# #### Model Development

# %% [markdown]
# ##### Baseline Model

# %%
#drop columns not needed
X = drop_columns(X)

# %%
# Keep selected columns only
my_cols = categorical_cols + numerical_cols
X = X[my_cols].copy()

# %%
X
# Out:
#      Street LotShape LandContour Utilities LandSlope MasVnrType ExterQual  \
# 0      Pave      Reg         Lvl    AllPub       Gtl    BrkFace        Gd
# 1      Pave      Reg         Lvl    AllPub       Gtl       None        TA
# 2      Pave      IR1         Lvl    AllPub       Gtl    BrkFace        Gd
# 3      Pave      IR1         Lvl    AllPub       Gtl       None        TA
# 4      Pave      IR1         Lvl    AllPub       Gtl    BrkFace        Gd
# ...     ...      ...         ...       ...       ...        ...       ...
# 1455   Pave      Reg         Lvl    AllPub       Gtl       None        TA
# 1456   Pave      Reg         Lvl    AllPub       Gtl      Stone        TA
# 1457   Pave      Reg         Lvl    AllPub       Gtl       None        Ex
# 1458   Pave      Reg         Lvl    AllPub       Gtl       None        TA
# 1459   Pave      Reg         Lvl    AllPub       Gtl       None        Gd
#
#      BsmtQual BsmtCond BsmtExposure  ... Fireplaces GarageYrBlt GarageCars  \
# ...
