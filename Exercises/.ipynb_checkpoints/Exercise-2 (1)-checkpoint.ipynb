# %% [markdown]
# # Exercise 2: Feature selection and tuning

# %% [markdown]
# ##### To Do
#
# - Load in the train data for the Housing prices Competition.
# - Understand the data
# - Using the skills learnt, improve on your submission from exercise 1
# - build a model on train data
# - make prediction on test
# - submit predictions on the kaggle competition.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # 1. Load the data

# %%
# Path of the file to read
competition_train_path = '../data/housing-prices-competition/train.csv'

competition_test_path = '../data/housing-prices-competition/test.csv'

competition_df = pd.read_csv(competition_train_path)
competition_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
test_df = pd.read_csv(competition_test_path)
test_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %% [markdown]
# # 2. Data comprehension

# %% [markdown]
# ### - Variables
# 1. The target variable
# 2. Possible features

# %%
# the SalePrice is right skewed
plt.hist(competition_df.SalePrice)
plt.xlabel("$")
plt.ylabel("Count")
plt.title("Sale Price")
plt.show()

# %%
# Normalising the target variable
competition_df["SalePrice"] = np.log1p(competition_df["SalePrice"])

# %%
plt.hist(competition_df.SalePrice)
plt.xlabel("log1($)")
plt.ylabel("Count")
plt.title("Sale Price Post-Transform")
plt.show()

# %%
print("Possible features")
print(list(competition_df.columns))
# Out:
# Possible features
# ...

# %% [markdown]
# ### - Distributions
# 1. Data type - Dtype (Num vs categorical)
# 2. Data variety value_counts()
# 3. Distribution in tabular, histogram, and covariance forms

# %%
competition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print("Watch out for skewed distributions ")
print("These are possible outliers.")
competition_df.describe()
# Out:
# Watch out for skewed distributions
# These are possible outliers.
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# ...

# %%
print('Observations: ')
print(' - Some large tails: LotArea, MasVnrArea, BsmtFinSF1; ')
print(' - A lot of categorical features that cannot be described by the stats above; ')
# Out:
# Observations:
#  - Some large tails: LotArea, MasVnrArea, BsmtFinSF1;
#  - A lot of categorical features that cannot be described by the stats above;

# %%
print("Look at the range of values in each columns.")
print("Are there columns with binary, integers, real, boolean values?")
for c in competition_df.columns:
    print("\n---- %s ---" % c)
    print(competition_df[c].value_counts())
# Out:
# Look at the range of values in each columns.
# Are there columns with binary, integers, real, boolean values?
#
# ---- Id ---
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: count, Length: 1460, dtype: int64
#
# ---- MSSubClass ---
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64
#
# ---- MSZoning ---
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# ---- LotFrontage ---
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64
#
# ---- LotArea ---
# LotArea
# ...

# %%
print('Observations:')
print(' - Mostly 1 Family buildings: 1220, 114, ...')
print(' - Mostly of medium to upper quality: 5,6, 7 - 397, 374, 319')
print(' - Mostly built in yearly 2000s: 2006, 2005, 2004 - 67, 64, 54')
print(' - Mostly heated with GasA: GasA, GasW: - 1428, 18, 7')
print(' - Just 2 streets and alleys with the same names and very different numbers : Street -  Pave    1454, Grvl       6; Alley - Grvl    50, Pave    41 ')
print(' - Just 2 types of highly skewed utilities: AllPub, NoSeWa - 1459, 1')
print(' - A variety of lot configs with majorities on Inside, Corner - 1052, 263, 94, 57, 4')
# Out:
# Observations:
#  - Mostly 1 Family buildings: 1220, 114, ...
#  - Mostly of medium to upper quality: 5,6, 7 - 397, 374, 319
#  - Mostly built in yearly 2000s: 2006, 2005, 2004 - 67, 64, 54
#  - Mostly heated with GasA: GasA, GasW: - 1428, 18, 7
#  - Just 2 streets and alleys with the same names and very different numbers : Street -  Pave    1454, Grvl       6; Alley - Grvl    50, Pave    41
#  - Just 2 types of highly skewed utilities: AllPub, NoSeWa - 1459, 1
#  - A variety of lot configs with majorities on Inside, Corner - 1052, 263, 94, 57, 4

# %% [markdown]
# ### Categorical features

# %%
cat_feat = competition_df.select_dtypes(include=[object])
cat_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   Alley          91 non-null     object
#  3   LotShape       1460 non-null   object
#  4   LandContour    1460 non-null   object
#  5   Utilities      1460 non-null   object
#  6   LotConfig      1460 non-null   object
#  7   LandSlope      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   Condition1     1460 non-null   object
#  10  Condition2     1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  HouseStyle     1460 non-null   object
#  13  RoofStyle      1460 non-null   object
#  14  RoofMatl       1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
cat_feat.nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        3
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       4
# SaleType          9
# SaleCondition     6
# dtype: int64

# %% [markdown]
# ### Numerical features

# %%
num_feat = competition_df.select_dtypes(include=[np.number])
num_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  LowQualFinSF   1460 non-null   int64
#  16  GrLivArea      1460 non-null   int64
#  17  BsmtFullBath   1460 non-null   int64
# ...

# %%
hist_distr = num_feat.hist(figsize = (30, 30))
hist_distr
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>],
#        [<Axes: title={'center': 'TotalBsmtSF'}>,
#         <Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>],
#        [<Axes: title={'center': 'BsmtHalfBath'}>,
#         <Axes: title={'center': 'FullBath'}>,
# ...

# %%
correlation_matrix = num_feat.corr()

plt.figure(figsize=(40, 40))

ax = sns.heatmap(
    correlation_matrix,
    vmax=1,
    square=True,
    annot=True,
    fmt='.2f',
    cmap='BuPu',
    cbar_kws={"shrink": .5},
    annot_kws={"size": 15},
    robust=True
)

plt.title('Correlation Matrix of features', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of features')

# %%
cm = np.abs(correlation_matrix[['SalePrice']]).sort_values(['SalePrice'], ascending = False)
cm
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.817185
# GrLivArea       0.700927
# GarageCars      0.680625
# GarageArea      0.650888
# TotalBsmtSF     0.612134
# 1stFlrSF        0.596981
# FullBath        0.594771
# YearBuilt       0.586570
# YearRemodAdd    0.565608
# GarageYrBlt     0.541073
# TotRmsAbvGrd    0.534422
# Fireplaces      0.489450
# MasVnrArea      0.430809
# BsmtFinSF1      0.372023
# LotFrontage     0.355879
# WoodDeckSF      0.334135
# OpenPorchSF     0.321053
# 2ndFlrSF        0.319300
# HalfBath        0.313982
# LotArea         0.257320
# BsmtFullBath    0.236224
# BsmtUnfSF       0.221985
# BedroomAbvGr    0.209043
# EnclosedPorch   0.149050
# KitchenAbvGr    0.147548
# ScreenPorch     0.121208
# MSSubClass      0.073959
# PoolArea        0.069798
# MoSold          0.057330
# 3SsnPorch       0.054900
# LowQualFinSF    0.037963
# YrSold          0.037263
# OverallCond     0.036868
# MiscVal         0.020021
# Id              0.017942
# ...

# %%
print('Observations:')
print('- Trial 1: select features with absolute correlation > 0.10')
thresh_1 = 0.1
features_1 = cm[cm['SalePrice']>thresh_1].index.drop('SalePrice')
print(features_1)
# Out:
# Observations:
# - Trial 1: select features with absolute correlation > 0.10
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
#        '1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt',
#        'TotRmsAbvGrd', 'Fireplaces', 'MasVnrArea', 'BsmtFinSF1', 'LotFrontage',
#        'WoodDeckSF', 'OpenPorchSF', '2ndFlrSF', 'HalfBath', 'LotArea',
#        'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr', 'EnclosedPorch',
#        'KitchenAbvGr', 'ScreenPorch'],
#       dtype='object')

# %%
features_1[0]
# Out:
# 'OverallQual'

# %% [markdown]
# ### Importance of correlated numerical features

# %%
temp_df_num = competition_df[features_1]
fig = plt.figure(figsize = (20, 80))
for i in range(len(temp_df_num.columns)):
    plt.subplot(len(features_1), 3, i + 1)
    sns.scatterplot(x = temp_df_num.columns[i], 
                    y = competition_df['SalePrice'], 
                    data = temp_df_num)
    plt.title(temp_df_num.columns[i])
fig.tight_layout(pad = 1.0)

# %% [markdown]
# Observations:
# - Clear lack of correlation: 'Id', ['MoSold', 'YrSold'] -> (!Also data leakage, only available after sale),
# - Likely lack of correlation: 'EnclosedPorch', 'ScreenPorch'
#
#
# - Slight correlation: 'GarageYrBlt',
# - Likely correlation: 'YearBuilt', 'GarageArea',
# - Clear correlation: 'GrLivArea'
#
#
# - Huge sparsity: 'MiscVal', 'PoolArea', '3SsnPorch', 'LowQualFinSF'
# - Data leakage: 'MoSold', 'YrSold'
# - Large variance: all the baths, bedroom, kitchen

# %%
high_corr = ['OverallQual', 'GrLivArea', 'TotalBsmtSF', '1stFlrSF' ]

likely_corr = ['GarageArea', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'TotRmsAbvGrd', 'BsmtFinSF1', '2ndFlrSF']

high_variance = ['GarageCars', 'Fireplaces', 'MasVnrArea', 'LotFrontage',   'WoodDeckSF', 'OpenPorchSF', 'HalfBath', 'LotArea',  'BtsmtFullBath', 'BedroomAbvGr' ,'KitchenAbvGr']

sparse = ['EnclosedPorch', 'ScreenPorch']

# %% [markdown]
# ## Encoding and Correlations of the categorical features

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
cat_feat = competition_df.select_dtypes(include=[object])

# %%
for c in cat_feat.columns:
    print("\n---- %s ---" % c)
    print(cat_feat[c].value_counts())
# Out:
# ---- MSZoning ---
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# ---- Street ---
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
#
# ---- Alley ---
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
#
# ---- LotShape ---
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
#
# ---- LandContour ---
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
#
# ---- Utilities ---
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
#
# ---- LotConfig ---
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
#
# ---- LandSlope ---
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
#
# ---- Neighborhood ---
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# ...

# %%
cat_feat_names =  ['LotConfig', 'Neighborhood', 'Condition1', 'BldgType',
'HouseStyle', 'Exterior1st', 'ExterQual','Foundation', 'HeatingQC',
'KitchenQual']

# %%
enc = OrdinalEncoder()
enc.fit_transform(cat_feat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 2
#       1 enc = OrdinalEncoder()
# ----> 2 enc.fit_transform(cat_feat).sort_values(['SalePrice'], ascending = False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'

# %%
# Out:
# OrdinalEncoder()

# %%
cat_corr_df = pd.DataFrame()
cat_corr_df[cat_feat.columns] = enc.fit_transform(cat_feat)
cat_corr_df['SalePrice'] = competition_df['SalePrice']
importance = np.abs(cat_corr_df.corr()['SalePrice']).sort_values(ascending = False)
importance
# Out:
# SalePrice        1.000000
# PoolQC           0.620295
# ExterQual        0.582164
# BsmtQual         0.572235
# GarageFinish     0.555218
# KitchenQual      0.534387
# Alley            0.482502
# GarageType       0.434539
# HeatingQC        0.425906
# Foundation       0.412083
# CentralAir       0.351599
# MasVnrType       0.327415
# PavedDrive       0.304687
# Electrical       0.294406
# LotShape         0.278091
# BsmtExposure     0.272313
# SaleCondition    0.248819
# HouseStyle       0.214717
# Fence            0.208197
# Neighborhood     0.201685
# GarageCond       0.198081
# MSZoning         0.188861
# RoofStyle        0.186917
# GarageQual       0.157833
# ExterCond        0.148561
# Heating          0.139919
# FireplaceQu      0.138336
# Functional       0.131367
# Exterior2nd      0.125785
# Exterior1st      0.121980
# Condition1       0.115896
# RoofMatl         0.107519
# MiscFeature      0.101302
# BsmtFinType1     0.090646
# BsmtCond         0.082661
# ...

# %%
features_2 = importance[importance>0.5].index.drop('SalePrice')
print(features_2)
# Out:
# Index(['PoolQC', 'ExterQual', 'BsmtQual', 'GarageFinish', 'KitchenQual'], dtype='object')

# %% [markdown]
# ## 4. Build the pipeline

# %% [markdown]
# ### Preprocessing

# %%
y = competition_df.SalePrice
X = competition_df.drop(['SalePrice'], axis=1)
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2)

numerical_cols = high_corr + likely_corr
categorical_cols = features_2.to_list()

print(numerical_cols)
print(categorical_cols)
my_cols = categorical_cols + numerical_cols

X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
# Out:
# ['OverallQual', 'GrLivArea', 'TotalBsmtSF', '1stFlrSF', 'GarageArea', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'TotRmsAbvGrd', 'BsmtFinSF1', '2ndFlrSF']
# ['PoolQC', 'ExterQual', 'BsmtQual', 'GarageFinish', 'KitchenQual']

# %%
# Preprocessing for numerical data
numerical_transformer = SimpleImputer()

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value = np.nan))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingClassifier
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

model_1 = RandomForestRegressor(random_state=0)
model_2 =  LinearRegression()

my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model_1)
                             ])

# %%
my_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   ['OverallQual', 'GrLivArea',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    'GarageArea', 'YearBuilt',
#                                                    'YearRemodAdd',
#                                                    'GarageYrBlt',
#                                                    'TotRmsAbvGrd', 'BsmtFinSF1',
#                                                    '2ndFlrSF']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinal',
# ...

# %%
# Preprocessing of validation data, get predictions
preds = my_pipeline.predict(X_valid.dropna())

# Evaluate the model
#score = mean_absolute_error(y_valid, preds)
#print('MAE:', score)
preds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[217], line 2
#       1 # Preprocessing of validation data, get predictions
# ----> 2 preds = my_pipeline.predict(X_valid.dropna())
#       4 # Evaluate the model
#       5 #score = mean_absolute_error(y_valid, preds)
#       6 #print('MAE:', score)
#       7 preds
#
# File ~/miniconda3/envs/dsr-ml-funds/lib/python3.12/site-packages/sklearn/pipeline.py:515, in Pipeline.predict(self, X, **predict_params)
#     513 for _, name, transform in self._iter(with_final=False):
#     514     Xt = transform.transform(Xt)
# --> 515 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/miniconda3/envs/dsr-ml-funds/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
# ...

# %%
results =my_pipeline.predict(test_df)

# %%
np.exp(results)
# Out:
# array([124492.30037031, 144517.43466887, 180030.42790371, ...,
#        147825.80751657, 117936.8102747 , 223946.65081463])

# %%
Output_forest = pd.DataFrame({'Id': test_df['Id'], 'SalePrice': np.exp(results)}).set_index('Id')
Output_forest.to_csv("output_forest_2.csv", sep=',')

# %% [markdown]
# Resources:
#
# https://www.kaggle.com/code/ryndova/housing-prices-competition-for-kaggle-learn-users

# %% [markdown]
# # Preprocessing of validation data, get predictions
# preds = my_pipeline.predict(X_valid)
#
# # Evaluate the model
# score = mean_absolute_error(y_valid, preds)
# print('MAE:', score)

# %% [markdown]
# # Preprocessing of validation data, get predictions
# preds = my_pipeline.predict(X_valid)
#
# # Evaluate the model
# score = mean_absolute_error(y_valid, preds)
# print('MAE:', score)
