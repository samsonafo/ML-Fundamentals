# %% [markdown]
# #### K-Nearest Neighbors

# %% [markdown]
# '''The KNN algorithm assumes that similar things exist in close proximity. In other words, similar things are near to each other.'''
#
# ![k-Nearest-Neigbhour](./img/knn.png)

# %% [markdown]
# Notice in the image above that most of the time, similar data points are close to each other.
#
# The KNN algorithm hinges on this assumption being true enough for the algorithm to be useful.
#
# KNN captures the idea of similarity (sometimes called distance, proximity, or closeness) with some mathematics we might have learned in our childhood— calculating the distance between points on a graph.

# %% [markdown]
# #### When do we use KNN algorithm?
#
# KNN can be used for both classification and regression predictive problems.
#
# However, it is more widely used in classification problems in the industry

# %% [markdown]
# ##### How does the KNN algorithm work?
#
# Let’s take a simple case to understand this algorithm. Following is a spread of red circles (RC) and green squares (GS) :
#
# ![k-Nearest-Neigbhour](./img/knn-scenario1.png)
#
# You intend to find out the class of the blue star (BS). BS can either be RC or GS and nothing else.
#
# The “K” is KNN algorithm is the nearest neighbor we wish to take the vote from. Let’s say K = 3. Hence, we will now make a circle with BS as the center just as big as to enclose only three datapoints on the plane. Refer to the following diagram for more details:
#
# ![k-Nearest-Neigbhour](./img/knn-scenario2.png)
#
# The three closest points to BS is all RC. Hence, with a good confidence level, we can say that the BS should belong to the class RC. Here, the choice became very obvious as all three votes from the closest neighbor went to RC. The choice of the parameter K is very crucial in this algorithm. Next, we will understand what are the factors to be considered to conclude the best K.

# %% [markdown]
# Exercise: Build a simple KNN ML Model. Test around with different values of n.

# %% [markdown]
# ### Data Check

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

# %%
#import data
df = pd.read_csv('./data/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#check for null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#check target column

df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %% [markdown]
# ## Exploratory Data Analysis

# %%
corr = df.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
plt.figure(figsize=(18,8))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ### Model Development - Classification

# %%
#assign X and y

y = df.quality
X = df.drop('quality',axis=1)

# %%
#split the data into train and validate

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.23, random_state=42)

# %%
#model

#define the model
knn = KNeighborsClassifier(n_neighbors=3)

#fit the model
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
#predict
preds = knn.predict(X_val)

# %%
#evaluate the model -- 
knn.score(X_val,y_val)
# Out:
# 0.45108695652173914

# %%
n_list = [1,2,3,4,5]

for x in n_list:
    knn = KNeighborsClassifier(n_neighbors=x)  #define the model
    knn.fit(X_train,y_train)
    train_score = knn.score(X_train,y_train)
    val_score = knn.score(X_val,y_val)
    
    print(f'for Train -- Nearest Neighbor value of {x}, we get the score {np.round(train_score,2)}')
    print(f'for Test -- Nearest Neighbor value of {x}, we get the score {np.round(val_score,2)}')
    print('.')
    print('.')
# Out:
# for Train -- Nearest Neighbor value of 1, we get the score 1.0
# for Test -- Nearest Neighbor value of 1, we get the score 0.54
# .
# .
# for Train -- Nearest Neighbor value of 2, we get the score 0.79
# for Test -- Nearest Neighbor value of 2, we get the score 0.45
# .
# .
# for Train -- Nearest Neighbor value of 3, we get the score 0.73
# for Test -- Nearest Neighbor value of 3, we get the score 0.45
# .
# .
# for Train -- Nearest Neighbor value of 4, we get the score 0.69
# for Test -- Nearest Neighbor value of 4, we get the score 0.45
# .
# .
# for Train -- Nearest Neighbor value of 5, we get the score 0.67
# for Test -- Nearest Neighbor value of 5, we get the score 0.46
# .
# .

# %% [markdown]
# ### Logistic Regression Implementation

# %%
#import libraries
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings("ignore")

# %%
#model development

#define the model
lr = LogisticRegression()

#fit the model
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#pedict
preds_lr = lr.predict(X_val)

# %%
#evaluate the model
lr.score(X_val,y_val)
# Out:
# 0.5597826086956522

# %%
lr.score(X_train,y_train)
# Out:
# 0.5848903330625508

# %%
f1_score(y_val, preds_lr, average='micro')
# Out:
# 0.5597826086956522

# %%
#compare the results
X_val['target value'] = y_val
X_val['predictions'] = preds_lr

# %%
X_val
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 1340            7.5              0.51         0.02            1.70      0.084
# 81              7.8              0.43         0.70            1.90      0.464
# 1495            7.0              0.43         0.02            1.90      0.080
# 438            10.4              0.41         0.55            3.20      0.076
# 1229            7.6              0.43         0.29            2.10      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 803                  14.0                  46.0  0.99710  3.24       0.66
# 124                  21.0                 102.0  0.99600  3.39       0.48
# 350                  17.0                  34.0  1.00040  3.28       0.98
# 682                  32.0                  58.0  0.99800  3.33       0.54
# 1326                 18.0                  34.0  0.99480  3.39       0.60
# ...                   ...                   ...      ...   ...        ...
# 1340                 13.0                  31.0  0.99538  3.36       0.54
# 81                   22.0                  67.0  0.99740  3.13       1.28
# 1495                 15.0                  28.0  0.99492  3.35       0.81
# 438                  22.0                  54.0  0.99960  3.15       0.89
# 1229                 19.0                  66.0  0.99718  3.40       0.64
#
#       alcohol  target value  predictions
# 803       9.6             6            5
# 124       9.5             5            5
# 350       9.9             6            5
# 682       9.8             5            5
# 1326     10.6             6            6
# ...       ...           ...          ...
# 1340     10.5             6            6
# 81        9.4             5            6
# 1495     10.6             6            6
# 438       9.9             6            6
# 1229      9.5             5            5
#
# [368 rows x 13 columns]
